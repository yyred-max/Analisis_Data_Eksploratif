# %% [markdown]
# <a href="https://colab.research.google.com/github/yyred-max/Analisis_Data_Eksploratif/blob/main/Latihan3_Yuliana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
dFrame=pd.DataFrame({'F':np.linspace(1,10,10)})
dFrame=pd.concat([dFrame,pd.DataFrame(np.random.rand(10,5), columns=list('EDCBA'))], axis=1)
dFrame
# Out:
#       F         E         D         C         B         A
# 0   1.0  0.410431  0.794460  0.993329  0.044486  0.894406
# 1   2.0  0.923561  0.349116  0.732767  0.488927  0.063951
# 2   3.0  0.947246  0.426794  0.466813  0.573881  0.175181
# 3   4.0  0.359196  0.082989  0.987933  0.779733  0.493924
# 4   5.0  0.877826  0.838412  0.212900  0.804598  0.032536
# 5   6.0  0.188920  0.643941  0.139255  0.808668  0.665245
# 6   7.0  0.133999  0.249862  0.227139  0.371298  0.235427
# 7   8.0  0.768148  0.293604  0.575404  0.641054  0.388295
# 8   9.0  0.984355  0.315572  0.727650  0.336817  0.982047
# 9  10.0  0.202003  0.976059  0.913678  0.359343  0.529914

# %%
#define a function to color
def Warna(value):
  if value < 0:
    color='red'
  elif value > 0:
    color='black'
  else:
    color='green'
  return 'color: %s' % color

# %%
s=dFrame.style.applymap(Warna,subset=['A','B','C','D','E'])
s
# Out:
# /tmp/ipykernel_3327/244736090.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   s=dFrame.style.applymap(Warna,subset=['A','B','C','D','E'])
# <style type="text/css">
# #T_bcfc2_row0_col1, #T_bcfc2_row0_col2, #T_bcfc2_row0_col3, #T_bcfc2_row0_col4, #T_bcfc2_row0_col5, #T_bcfc2_row1_col1, #T_bcfc2_row1_col2, #T_bcfc2_row1_col3, #T_bcfc2_row1_col4, #T_bcfc2_row1_col5, #T_bcfc2_row2_col1, #T_bcfc2_row2_col2, #T_bcfc2_row2_col3, #T_bcfc2_row2_col4, #T_bcfc2_row2_col5, #T_bcfc2_row3_col1, #T_bcfc2_row3_col2, #T_bcfc2_row3_col3, #T_bcfc2_row3_col4, #T_bcfc2_row3_col5, #T_bcfc2_row4_col1, #T_bcfc2_row4_col2, #T_bcfc2_row4_col3, #T_bcfc2_row4_col4, #T_bcfc2_row4_col5, #T_bcfc2_row5_col1, #T_bcfc2_row5_col2, #T_bcfc2_row5_col3, #T_bcfc2_row5_col4, #T_bcfc2_row5_col5, #T_bcfc2_row6_col1, #T_bcfc2_row6_col2, #T_bcfc2_row6_col3, #T_bcfc2_row6_col4, #T_bcfc2_row6_col5, #T_bcfc2_row7_col1, #T_bcfc2_row7_col2, #T_bcfc2_row7_col3, #T_bcfc2_row7_col4, #T_bcfc2_row7_col5, #T_bcfc2_row8_col1, #T_bcfc2_row8_col2, #T_bcfc2_row8_col3, #T_bcfc2_row8_col4, #T_bcfc2_row8_col5, #T_bcfc2_row9_col1, #T_bcfc2_row9_col2, #T_bcfc2_row9_col3, #T_bcfc2_row9_col4, #T_bcfc2_row9_col5 {
#   color: black;
# }
# </style>
# <table id="T_bcfc2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcfc2_level0_col0" class="col_heading level0 col0" >F</th>
#       <th id="T_bcfc2_level0_col1" class="col_heading level0 col1" >E</th>
#       <th id="T_bcfc2_level0_col2" class="col_heading level0 col2" >D</th>
#       <th id="T_bcfc2_level0_col3" class="col_heading level0 col3" >C</th>
#       <th id="T_bcfc2_level0_col4" class="col_heading level0 col4" >B</th>
#       <th id="T_bcfc2_level0_col5" class="col_heading level0 col5" >A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcfc2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bcfc2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_bcfc2_row0_col1" class="data row0 col1" >0.410431</td>
#       <td id="T_bcfc2_row0_col2" class="data row0 col2" >0.794460</td>
#       <td id="T_bcfc2_row0_col3" class="data row0 col3" >0.993329</td>
#       <td id="T_bcfc2_row0_col4" class="data row0 col4" >0.044486</td>
#       <td id="T_bcfc2_row0_col5" class="data row0 col5" >0.894406</td>
#     </tr>
#     <tr>
#       <th id="T_bcfc2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bcfc2_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_bcfc2_row1_col1" class="data row1 col1" >0.923561</td>
#       <td id="T_bcfc2_row1_col2" class="data row1 col2" >0.349116</td>
#       <td id="T_bcfc2_row1_col3" class="data row1 col3" >0.732767</td>
#       <td id="T_bcfc2_row1_col4" class="data row1 col4" >0.488927</td>
#       <td id="T_bcfc2_row1_col5" class="data row1 col5" >0.063951</td>
#     </tr>
#     <tr>
#       <th id="T_bcfc2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bcfc2_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_bcfc2_row2_col1" class="data row2 col1" >0.947246</td>
#       <td id="T_bcfc2_row2_col2" class="data row2 col2" >0.426794</td>
#       <td id="T_bcfc2_row2_col3" class="data row2 col3" >0.466813</td>
#       <td id="T_bcfc2_row2_col4" class="data row2 col4" >0.573881</td>
#       <td id="T_bcfc2_row2_col5" class="data row2 col5" >0.175181</td>
#     </tr>
#     <tr>
#       <th id="T_bcfc2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bcfc2_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_bcfc2_row3_col1" class="data row3 col1" >0.359196</td>
#       <td id="T_bcfc2_row3_col2" class="data row3 col2" >0.082989</td>
#       <td id="T_bcfc2_row3_col3" class="data row3 col3" >0.987933</td>
#       <td id="T_bcfc2_row3_col4" class="data row3 col4" >0.779733</td>
#       <td id="T_bcfc2_row3_col5" class="data row3 col5" >0.493924</td>
#     </tr>
#     <tr>
#       <th id="T_bcfc2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bcfc2_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_bcfc2_row4_col1" class="data row4 col1" >0.877826</td>
#       <td id="T_bcfc2_row4_col2" class="data row4 col2" >0.838412</td>
#       <td id="T_bcfc2_row4_col3" class="data row4 col3" >0.212900</td>
#       <td id="T_bcfc2_row4_col4" class="data row4 col4" >0.804598</td>
#       <td id="T_bcfc2_row4_col5" class="data row4 col5" >0.032536</td>
#     </tr>
#     <tr>
#       <th id="T_bcfc2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bcfc2_row5_col0" class="data row5 col0" >6.000000</td>
#       <td id="T_bcfc2_row5_col1" class="data row5 col1" >0.188920</td>
#       <td id="T_bcfc2_row5_col2" class="data row5 col2" >0.643941</td>
#       <td id="T_bcfc2_row5_col3" class="data row5 col3" >0.139255</td>
#       <td id="T_bcfc2_row5_col4" class="data row5 col4" >0.808668</td>
#       <td id="T_bcfc2_row5_col5" class="data row5 col5" >0.665245</td>
#     </tr>
#     <tr>
#       <th id="T_bcfc2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bcfc2_row6_col0" class="data row6 col0" >7.000000</td>
#       <td id="T_bcfc2_row6_col1" class="data row6 col1" >0.133999</td>
#       <td id="T_bcfc2_row6_col2" class="data row6 col2" >0.249862</td>
#       <td id="T_bcfc2_row6_col3" class="data row6 col3" >0.227139</td>
#       <td id="T_bcfc2_row6_col4" class="data row6 col4" >0.371298</td>
#       <td id="T_bcfc2_row6_col5" class="data row6 col5" >0.235427</td>
#     </tr>
#     <tr>
#       <th id="T_bcfc2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bcfc2_row7_col0" class="data row7 col0" >8.000000</td>
#       <td id="T_bcfc2_row7_col1" class="data row7 col1" >0.768148</td>
#       <td id="T_bcfc2_row7_col2" class="data row7 col2" >0.293604</td>
#       <td id="T_bcfc2_row7_col3" class="data row7 col3" >0.575404</td>
#       <td id="T_bcfc2_row7_col4" class="data row7 col4" >0.641054</td>
#       <td id="T_bcfc2_row7_col5" class="data row7 col5" >0.388295</td>
#     </tr>
#     <tr>
#       <th id="T_bcfc2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bcfc2_row8_col0" class="data row8 col0" >9.000000</td>
#       <td id="T_bcfc2_row8_col1" class="data row8 col1" >0.984355</td>
#       <td id="T_bcfc2_row8_col2" class="data row8 col2" >0.315572</td>
#       <td id="T_bcfc2_row8_col3" class="data row8 col3" >0.727650</td>
#       <td id="T_bcfc2_row8_col4" class="data row8 col4" >0.336817</td>
#       <td id="T_bcfc2_row8_col5" class="data row8 col5" >0.982047</td>
#     </tr>
#     <tr>
#       <th id="T_bcfc2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bcfc2_row9_col0" class="data row9 col0" >10.000000</td>
#       <td id="T_bcfc2_row9_col1" class="data row9 col1" >0.202003</td>
#       <td id="T_bcfc2_row9_col2" class="data row9 col2" >0.976059</td>
#       <td id="T_bcfc2_row9_col3" class="data row9 col3" >0.913678</td>
#       <td id="T_bcfc2_row9_col4" class="data row9 col4" >0.359343</td>
#       <td id="T_bcfc2_row9_col5" class="data row9 col5" >0.529914</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Higlight Bilangan Maximum dengan warna orange, minimum dengan warna hijau
def highlight(x):
  Maksimum = x == x.max()
  return ['background-color:orange'if v else '' for v in Maksimum]

def highlight2(x):
  Minimum = x == x.min()
  return ['background-color:green'if v else '' for v in Minimum]

# %%
dFrame.style.apply(highlight).apply(highlight2).highlight_null(color='red')
# Out:
# <style type="text/css">
# #T_2e158_row0_col0, #T_2e158_row0_col4, #T_2e158_row3_col2, #T_2e158_row4_col5, #T_2e158_row5_col3, #T_2e158_row6_col1 {
#   background-color: green;
# }
# #T_2e158_row0_col3, #T_2e158_row5_col4, #T_2e158_row8_col1, #T_2e158_row8_col5, #T_2e158_row9_col0, #T_2e158_row9_col2 {
#   background-color: orange;
# }
# </style>
# <table id="T_2e158" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e158_level0_col0" class="col_heading level0 col0" >F</th>
#       <th id="T_2e158_level0_col1" class="col_heading level0 col1" >E</th>
#       <th id="T_2e158_level0_col2" class="col_heading level0 col2" >D</th>
#       <th id="T_2e158_level0_col3" class="col_heading level0 col3" >C</th>
#       <th id="T_2e158_level0_col4" class="col_heading level0 col4" >B</th>
#       <th id="T_2e158_level0_col5" class="col_heading level0 col5" >A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e158_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e158_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2e158_row0_col1" class="data row0 col1" >0.410431</td>
#       <td id="T_2e158_row0_col2" class="data row0 col2" >0.794460</td>
#       <td id="T_2e158_row0_col3" class="data row0 col3" >0.993329</td>
#       <td id="T_2e158_row0_col4" class="data row0 col4" >0.044486</td>
#       <td id="T_2e158_row0_col5" class="data row0 col5" >0.894406</td>
#     </tr>
#     <tr>
#       <th id="T_2e158_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e158_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_2e158_row1_col1" class="data row1 col1" >0.923561</td>
#       <td id="T_2e158_row1_col2" class="data row1 col2" >0.349116</td>
#       <td id="T_2e158_row1_col3" class="data row1 col3" >0.732767</td>
#       <td id="T_2e158_row1_col4" class="data row1 col4" >0.488927</td>
#       <td id="T_2e158_row1_col5" class="data row1 col5" >0.063951</td>
#     </tr>
#     <tr>
#       <th id="T_2e158_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2e158_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_2e158_row2_col1" class="data row2 col1" >0.947246</td>
#       <td id="T_2e158_row2_col2" class="data row2 col2" >0.426794</td>
#       <td id="T_2e158_row2_col3" class="data row2 col3" >0.466813</td>
#       <td id="T_2e158_row2_col4" class="data row2 col4" >0.573881</td>
#       <td id="T_2e158_row2_col5" class="data row2 col5" >0.175181</td>
#     </tr>
#     <tr>
#       <th id="T_2e158_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2e158_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_2e158_row3_col1" class="data row3 col1" >0.359196</td>
#       <td id="T_2e158_row3_col2" class="data row3 col2" >0.082989</td>
#       <td id="T_2e158_row3_col3" class="data row3 col3" >0.987933</td>
#       <td id="T_2e158_row3_col4" class="data row3 col4" >0.779733</td>
#       <td id="T_2e158_row3_col5" class="data row3 col5" >0.493924</td>
#     </tr>
#     <tr>
#       <th id="T_2e158_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2e158_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_2e158_row4_col1" class="data row4 col1" >0.877826</td>
#       <td id="T_2e158_row4_col2" class="data row4 col2" >0.838412</td>
#       <td id="T_2e158_row4_col3" class="data row4 col3" >0.212900</td>
#       <td id="T_2e158_row4_col4" class="data row4 col4" >0.804598</td>
#       <td id="T_2e158_row4_col5" class="data row4 col5" >0.032536</td>
#     </tr>
#     <tr>
#       <th id="T_2e158_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2e158_row5_col0" class="data row5 col0" >6.000000</td>
#       <td id="T_2e158_row5_col1" class="data row5 col1" >0.188920</td>
#       <td id="T_2e158_row5_col2" class="data row5 col2" >0.643941</td>
#       <td id="T_2e158_row5_col3" class="data row5 col3" >0.139255</td>
#       <td id="T_2e158_row5_col4" class="data row5 col4" >0.808668</td>
#       <td id="T_2e158_row5_col5" class="data row5 col5" >0.665245</td>
#     </tr>
#     <tr>
#       <th id="T_2e158_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2e158_row6_col0" class="data row6 col0" >7.000000</td>
#       <td id="T_2e158_row6_col1" class="data row6 col1" >0.133999</td>
#       <td id="T_2e158_row6_col2" class="data row6 col2" >0.249862</td>
#       <td id="T_2e158_row6_col3" class="data row6 col3" >0.227139</td>
#       <td id="T_2e158_row6_col4" class="data row6 col4" >0.371298</td>
#       <td id="T_2e158_row6_col5" class="data row6 col5" >0.235427</td>
#     </tr>
#     <tr>
#       <th id="T_2e158_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2e158_row7_col0" class="data row7 col0" >8.000000</td>
#       <td id="T_2e158_row7_col1" class="data row7 col1" >0.768148</td>
#       <td id="T_2e158_row7_col2" class="data row7 col2" >0.293604</td>
#       <td id="T_2e158_row7_col3" class="data row7 col3" >0.575404</td>
#       <td id="T_2e158_row7_col4" class="data row7 col4" >0.641054</td>
#       <td id="T_2e158_row7_col5" class="data row7 col5" >0.388295</td>
#     </tr>
#     <tr>
#       <th id="T_2e158_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2e158_row8_col0" class="data row8 col0" >9.000000</td>
#       <td id="T_2e158_row8_col1" class="data row8 col1" >0.984355</td>
#       <td id="T_2e158_row8_col2" class="data row8 col2" >0.315572</td>
#       <td id="T_2e158_row8_col3" class="data row8 col3" >0.727650</td>
#       <td id="T_2e158_row8_col4" class="data row8 col4" >0.336817</td>
#       <td id="T_2e158_row8_col5" class="data row8 col5" >0.982047</td>
#     </tr>
#     <tr>
#       <th id="T_2e158_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2e158_row9_col0" class="data row9 col0" >10.000000</td>
#       <td id="T_2e158_row9_col1" class="data row9 col1" >0.202003</td>
#       <td id="T_2e158_row9_col2" class="data row9 col2" >0.976059</td>
#       <td id="T_2e158_row9_col3" class="data row9 col3" >0.913678</td>
#       <td id="T_2e158_row9_col4" class="data row9 col4" >0.359343</td>
#       <td id="T_2e158_row9_col5" class="data row9 col5" >0.529914</td>
#     </tr>
#   </tbody>
# </table>

# %%
import seaborn as sns
colorMap=sns.light_palette("blue", as_cmap=True)
Gradasi=dFrame.style.background_gradient(cmap=colorMap)
Gradasi
# Out:
# <style type="text/css">
# #T_952b2_row0_col0, #T_952b2_row0_col4, #T_952b2_row3_col2, #T_952b2_row4_col5, #T_952b2_row5_col3, #T_952b2_row6_col1 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_952b2_row0_col1 {
#   background-color: #a2a2f7;
#   color: #f1f1f1;
# }
# #T_952b2_row0_col2 {
#   background-color: #3131fd;
#   color: #f1f1f1;
# }
# #T_952b2_row0_col3, #T_952b2_row5_col4, #T_952b2_row8_col1, #T_952b2_row8_col5, #T_952b2_row9_col0, #T_952b2_row9_col2 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_952b2_row0_col5, #T_952b2_row9_col3 {
#   background-color: #1616fe;
#   color: #f1f1f1;
# }
# #T_952b2_row1_col0 {
#   background-color: #d6d6f4;
#   color: #000000;
# }
# #T_952b2_row1_col1 {
#   background-color: #1111fe;
#   color: #f1f1f1;
# }
# #T_952b2_row1_col2 {
#   background-color: #a9a9f6;
#   color: #000000;
# }
# #T_952b2_row1_col3, #T_952b2_row2_col4, #T_952b2_row8_col3 {
#   background-color: #4a4afb;
#   color: #f1f1f1;
# }
# #T_952b2_row1_col4 {
#   background-color: #6565fa;
#   color: #f1f1f1;
# }
# #T_952b2_row1_col5 {
#   background-color: #e9e9f3;
#   color: #000000;
# }
# #T_952b2_row2_col0 {
#   background-color: #bcbcf5;
#   color: #000000;
# }
# #T_952b2_row2_col1 {
#   background-color: #0a0afe;
#   color: #f1f1f1;
# }
# #T_952b2_row2_col2, #T_952b2_row2_col3 {
#   background-color: #9494f7;
#   color: #f1f1f1;
# }
# #T_952b2_row2_col5 {
#   background-color: #cdcdf5;
#   color: #000000;
# }
# #T_952b2_row3_col0 {
#   background-color: #a0a0f7;
#   color: #f1f1f1;
# }
# #T_952b2_row3_col1 {
#   background-color: #b1b1f6;
#   color: #000000;
# }
# #T_952b2_row3_col3, #T_952b2_row4_col4 {
#   background-color: #0101ff;
#   color: #f1f1f1;
# }
# #T_952b2_row3_col4 {
#   background-color: #0808ff;
#   color: #f1f1f1;
# }
# #T_952b2_row3_col5 {
#   background-color: #7c7cf9;
#   color: #f1f1f1;
# }
# #T_952b2_row4_col0 {
#   background-color: #8686f8;
#   color: #f1f1f1;
# }
# #T_952b2_row4_col1 {
#   background-color: #1e1efd;
#   color: #f1f1f1;
# }
# #T_952b2_row4_col2 {
#   background-color: #2525fd;
#   color: #f1f1f1;
# }
# #T_952b2_row4_col3 {
#   background-color: #dcdcf4;
#   color: #000000;
# }
# #T_952b2_row5_col0 {
#   background-color: #6b6bfa;
#   color: #f1f1f1;
# }
# #T_952b2_row5_col1 {
#   background-color: #e1e1f4;
#   color: #000000;
# }
# #T_952b2_row5_col2 {
#   background-color: #5a5afa;
#   color: #f1f1f1;
# }
# #T_952b2_row5_col5, #T_952b2_row6_col0 {
#   background-color: #5050fb;
#   color: #f1f1f1;
# }
# #T_952b2_row6_col2 {
#   background-color: #c4c4f5;
#   color: #000000;
# }
# #T_952b2_row6_col3 {
#   background-color: #d8d8f4;
#   color: #000000;
# }
# #T_952b2_row6_col4 {
#   background-color: #8a8af8;
#   color: #f1f1f1;
# }
# #T_952b2_row6_col5 {
#   background-color: #bebef5;
#   color: #000000;
# }
# #T_952b2_row7_col0, #T_952b2_row7_col4 {
#   background-color: #3535fc;
#   color: #f1f1f1;
# }
# #T_952b2_row7_col1 {
#   background-color: #3d3dfc;
#   color: #f1f1f1;
# }
# #T_952b2_row7_col2 {
#   background-color: #b8b8f6;
#   color: #000000;
# }
# #T_952b2_row7_col3 {
#   background-color: #7676f9;
#   color: #f1f1f1;
# }
# #T_952b2_row7_col5 {
#   background-color: #9797f7;
#   color: #f1f1f1;
# }
# #T_952b2_row8_col0 {
#   background-color: #1a1afe;
#   color: #f1f1f1;
# }
# #T_952b2_row8_col2 {
#   background-color: #b2b2f6;
#   color: #000000;
# }
# #T_952b2_row8_col4 {
#   background-color: #9595f7;
#   color: #f1f1f1;
# }
# #T_952b2_row9_col1 {
#   background-color: #dedef4;
#   color: #000000;
# }
# #T_952b2_row9_col4 {
#   background-color: #8d8df8;
#   color: #f1f1f1;
# }
# #T_952b2_row9_col5 {
#   background-color: #7272f9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_952b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_952b2_level0_col0" class="col_heading level0 col0" >F</th>
#       <th id="T_952b2_level0_col1" class="col_heading level0 col1" >E</th>
#       <th id="T_952b2_level0_col2" class="col_heading level0 col2" >D</th>
#       <th id="T_952b2_level0_col3" class="col_heading level0 col3" >C</th>
#       <th id="T_952b2_level0_col4" class="col_heading level0 col4" >B</th>
#       <th id="T_952b2_level0_col5" class="col_heading level0 col5" >A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_952b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_952b2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_952b2_row0_col1" class="data row0 col1" >0.410431</td>
#       <td id="T_952b2_row0_col2" class="data row0 col2" >0.794460</td>
#       <td id="T_952b2_row0_col3" class="data row0 col3" >0.993329</td>
#       <td id="T_952b2_row0_col4" class="data row0 col4" >0.044486</td>
#       <td id="T_952b2_row0_col5" class="data row0 col5" >0.894406</td>
#     </tr>
#     <tr>
#       <th id="T_952b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_952b2_row1_col0" class="data row1 col0" >2.000000</td>
#       <td id="T_952b2_row1_col1" class="data row1 col1" >0.923561</td>
#       <td id="T_952b2_row1_col2" class="data row1 col2" >0.349116</td>
#       <td id="T_952b2_row1_col3" class="data row1 col3" >0.732767</td>
#       <td id="T_952b2_row1_col4" class="data row1 col4" >0.488927</td>
#       <td id="T_952b2_row1_col5" class="data row1 col5" >0.063951</td>
#     </tr>
#     <tr>
#       <th id="T_952b2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_952b2_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_952b2_row2_col1" class="data row2 col1" >0.947246</td>
#       <td id="T_952b2_row2_col2" class="data row2 col2" >0.426794</td>
#       <td id="T_952b2_row2_col3" class="data row2 col3" >0.466813</td>
#       <td id="T_952b2_row2_col4" class="data row2 col4" >0.573881</td>
#       <td id="T_952b2_row2_col5" class="data row2 col5" >0.175181</td>
#     </tr>
#     <tr>
#       <th id="T_952b2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_952b2_row3_col0" class="data row3 col0" >4.000000</td>
#       <td id="T_952b2_row3_col1" class="data row3 col1" >0.359196</td>
#       <td id="T_952b2_row3_col2" class="data row3 col2" >0.082989</td>
#       <td id="T_952b2_row3_col3" class="data row3 col3" >0.987933</td>
#       <td id="T_952b2_row3_col4" class="data row3 col4" >0.779733</td>
#       <td id="T_952b2_row3_col5" class="data row3 col5" >0.493924</td>
#     </tr>
#     <tr>
#       <th id="T_952b2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_952b2_row4_col0" class="data row4 col0" >5.000000</td>
#       <td id="T_952b2_row4_col1" class="data row4 col1" >0.877826</td>
#       <td id="T_952b2_row4_col2" class="data row4 col2" >0.838412</td>
#       <td id="T_952b2_row4_col3" class="data row4 col3" >0.212900</td>
#       <td id="T_952b2_row4_col4" class="data row4 col4" >0.804598</td>
#       <td id="T_952b2_row4_col5" class="data row4 col5" >0.032536</td>
#     </tr>
#     <tr>
#       <th id="T_952b2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_952b2_row5_col0" class="data row5 col0" >6.000000</td>
#       <td id="T_952b2_row5_col1" class="data row5 col1" >0.188920</td>
#       <td id="T_952b2_row5_col2" class="data row5 col2" >0.643941</td>
#       <td id="T_952b2_row5_col3" class="data row5 col3" >0.139255</td>
#       <td id="T_952b2_row5_col4" class="data row5 col4" >0.808668</td>
#       <td id="T_952b2_row5_col5" class="data row5 col5" >0.665245</td>
#     </tr>
#     <tr>
#       <th id="T_952b2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_952b2_row6_col0" class="data row6 col0" >7.000000</td>
#       <td id="T_952b2_row6_col1" class="data row6 col1" >0.133999</td>
#       <td id="T_952b2_row6_col2" class="data row6 col2" >0.249862</td>
#       <td id="T_952b2_row6_col3" class="data row6 col3" >0.227139</td>
#       <td id="T_952b2_row6_col4" class="data row6 col4" >0.371298</td>
#       <td id="T_952b2_row6_col5" class="data row6 col5" >0.235427</td>
#     </tr>
#     <tr>
#       <th id="T_952b2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_952b2_row7_col0" class="data row7 col0" >8.000000</td>
#       <td id="T_952b2_row7_col1" class="data row7 col1" >0.768148</td>
#       <td id="T_952b2_row7_col2" class="data row7 col2" >0.293604</td>
#       <td id="T_952b2_row7_col3" class="data row7 col3" >0.575404</td>
#       <td id="T_952b2_row7

# %%
import matplotlib.pyplot as plt
from IPython.display import Math, Latex
from IPython.core.display import Image
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize':(10,6)})
from scipy.stats import uniform
number=10000
start=20
width=25
uniform_data=uniform.rvs(size=number,loc=start, scale=width)
axis = sns.histplot(uniform_data, bins=100, kde=True, color='skyblue', linewidth=15)
axis.set(xlabel='Distribusi Uniform', ylabel='Frekuensi')
# Out:
# [Text(0.5, 0, 'Distribusi Uniform'), Text(0, 0.5, 'Frekuensi')]

# %%
import matplotlib.pyplot as plt
from IPython.display import Math, Latex
from IPython.core.display import Image
import seaborn as sns
sns.set(color_codes=True)
sns.set(rc={'figure.figsize': (10,6)})
from scipy.stats import uniform
number=10000
start=20
width=25
uniform_data=uniform.rvs(size=number,loc=start, scale=width)
axis = sns.distplot(uniform_data, bins=100, kde=True, color='skyblue', hist_kws={"linewidth":15})
axis.set(xlabel='Distribusi Uniform',ylabel='Frekuensi')
# Out:
# /tmp/ipykernel_3327/94067446.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis = sns.distplot(uniform_data, bins=100, kde=True, color='skyblue', hist_kws={"linewidth":15})
# [Text(0.5, 0, 'Distribusi Uniform'), Text(0, 0.5, 'Frekuensi')]

# %%
#Distribusi Normal
from scipy.stats import norm
normal_data=norm.rvs(size=90000,loc=20,scale=30)
axis=sns.displot(normal_data,bins=100, kde=True, color='skyblue',
                 linewidth=15, alpha=0.568)
axis.set(xlabel='Distribusi Normal', ylabel='Frekuensi')

# %%
#DISTRIBUSI EKSPONENSIAL
from scipy.stats import expon
expon_data=expon.rvs (scale=1,loc=0,size=1000)
axis=sns.distplot(expon_data, kde=True, bins=100, color='skyblue',
hist_kws={"linewidth":15})
axis.set(xlabel='Distribusi eksponensial',ylabel='Frekuensi')
# Out:
# /tmp/ipykernel_3327/1867493903.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis=sns.distplot(expon_data, kde=True, bins=100, color='skyblue',
# [Text(0.5, 0, 'Distribusi eksponensial'), Text(0, 0.5, 'Frekuensi')]

# %%
#DISTRIBUSI EKSPONENSIAL
from scipy.stats import expon
expon_data=expon.rvs (scale=1,loc=0,size=1000)
axis=sns.histplot(expon_data, kde=True, bins=100, color='skyblue',
linewidth=15)
axis.set(xlabel='Distribusi eksponensial',ylabel='Frekuensi')
# Out:
# [Text(0.5, 0, 'Distribusi eksponensial'), Text(0, 0.5, 'Frekuensi')]

# %%
#DISTRIBUSI BINOMIAL
from scipy.stats import binom
binomial_data=binom.rvs(n=10,p=0.8, size=10000)
axis=sns.distplot (binomial_data, kde=False, color='red',
hist_kws={"linewidth":15})
axis.set(xlabel='Distribusi Binomial',ylabel='Frekuensi')
# Out:
# /tmp/ipykernel_3327/171823524.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axis=sns.distplot (binomial_data, kde=False, color='red',
# [Text(0.5, 0, 'Distribusi Binomial'), Text(0, 0.5, 'Frekuensi')]

# %%
#DISTRIBUSI BINOMIAL
from scipy.stats import binom
binomial_data=binom.rvs(n=10,p=0.8, size=10000)
axis=sns.histplot (binomial_data, kde=False, color='red',
linewidth=15)
axis.set(xlabel='Distribusi Binomial',ylabel='Frekuensi')
# Out:
# [Text(0.5, 0, 'Distribusi Binomial'), Text(0, 0.5, 'Frekuensi')]
